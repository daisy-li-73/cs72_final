# %%
import pandas as pd

# %%
rot_tom_df = pd.read_csv("rotten_tomatoes_movies.csv")

rot_tom_df.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
# ...

# %%
imsdb_df = pd.read_csv("imsdb_movies.csv", header=None, names=range(7))

imsdb_df["people"] = imsdb_df.iloc[:, 1:].apply(lambda row: ','.join(row.dropna().astype(str)), axis=1)
imsdb_df.rename(columns={0: 'movie_title'}, inplace=True)
imsdb_df.head()
# Out:
#                   movie_title                    1              2  \
# 0  10 Things I Hate About You  Karen McCullah Lutz  Kirsten Smith
# 1                          12     Lawrence Bridges            NaN
# 2              12 and Holding     Anthony Cipriano            NaN
# 3                  12 Monkeys        David Peoples  Janet Peoples
# 4            12 Years a Slave          John Ridley            NaN
#
#                      3    4    5    6  \
# 0  William Shakespeare  NaN  NaN  NaN
# 1                  NaN  NaN  NaN  NaN
# 2                  NaN  NaN  NaN  NaN
# 3                  NaN  NaN  NaN  NaN
# 4                  NaN  NaN  NaN  NaN
#
#                                               people
# 0  Karen McCullah Lutz,Kirsten Smith,William Shak...
# 1                                   Lawrence Bridges
# 2                                   Anthony Cipriano
# 3                        David Peoples,Janet Peoples
# 4                                        John Ridley

# %%
rot_tom_df[rot_tom_df["movie_title"] == "10 Things I Hate About You"]

combined_df = imsdb_df.merge(rot_tom_df, how = "left", on = "movie_title")
combined_df.head()
# Out:
#                   movie_title                    1              2  \
# 0  10 Things I Hate About You  Karen McCullah Lutz  Kirsten Smith
# 1                          12     Lawrence Bridges            NaN
# 2              12 and Holding     Anthony Cipriano            NaN
# 3                  12 Monkeys        David Peoples  Janet Peoples
# 4            12 Years a Slave          John Ridley            NaN
#
#                      3    4    5    6  \
# 0  William Shakespeare  NaN  NaN  NaN
# 1                  NaN  NaN  NaN  NaN
# 2                  NaN  NaN  NaN  NaN
# 3                  NaN  NaN  NaN  NaN
# 4                  NaN  NaN  NaN  NaN
#
#                                               people  \
# 0  Karen McCullah Lutz,Kirsten Smith,William Shak...
# 1                                   Lawrence Bridges
# 2                                   Anthony Cipriano
# 3                        David Peoples,Janet Peoples
# 4                                        John Ridley
#
# ...

# %%
combined_df[combined_df["rotten_tomatoes_link"].isna()]
# Out:
#                     movie_title                   1              2  \
# 2                12 and Holding    Anthony Cipriano            NaN
# 3                    12 Monkeys       David Peoples  Janet Peoples
# 9                           187      Scott Yagemann            NaN
# 18                      48 Hrs.  Steven E. De Souza    Walter Hill
# 19                        50-50         Will Reiser            NaN
# ...                         ...                 ...            ...
# 1276        World is not Enough                 The    Neal Purvis
# 1277                   Wrestler                 The     Rob Siegel
# 1278  X-Files: Fight the Future                 The   Chris Carter
# 1280   X-Men Origins: Wolverine       David Benioff     Skip Woods
# 1281                        xXx         Rich Wilkes            NaN
#
#                        3                4            5    6  \
# 2                    NaN              NaN          NaN  NaN
# ...
